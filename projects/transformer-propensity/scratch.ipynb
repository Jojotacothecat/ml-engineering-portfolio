# %% [markdown]
# # Scatch

# %%
import sys
print(sys.executable)
# Out:
# /Users/jojowang/ml-engineering-portfolio/projects/transformer-propensity/.venv/bin/python

# %%
import numpy as np, torch, torch.nn as nn, math
from sklearn.metrics import roc_auc_score

# %%
SEED = 42
N = 80000 # tiny. real run will be 8MM. 
T = 8
OOT_WEEK = 17
rng = np.random.default_rng(SEED) # random number generator for data 
torch.manual_seed(SEED) # random number generator for torch
